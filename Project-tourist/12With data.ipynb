# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait as wait

import pandas as pd

import time
import datetime
import threading

from bs4 import BeautifulSoup as bs

import smtplib
from email.mime.multipart import MIMEMultipart

# %%
flag = 0
for i in range(105,300):
    today = datetime.datetime.now() + datetime.timedelta(days=i)
    tostr = today.strftime('%Y/%m/%d')
    #     end_date = today + datetime.timedelta(days=5) + datetime.timedelta(days=i)
    #     enstr = end_date.strftime('%Y/%m/%d')

    browser = webdriver.Chrome(executable_path='driver/chromedriver')
    browser.get('https://www.tigerairtw.com/zh-tw')
    print(i,tostr)
    #     print(tostr,enstr)

    try:
        time.sleep(4)
        #checkbox
        browser.execute_script("document.getElementsByClassName('class_type')[1].setAttribute('checked', true)")
    #         checkboxs=browser.find_elements_by_class_name('class_type')
    #         for checkbox in checkboxs:
    #             print(checkbox.get_attribute('value'),checkbox.get_attribute('checked')

        # select part
        s1 = Select(browser.find_element_by_class_name('selectOrigin'))
    #     for select in s1.options:
    #         print(select.text, select.get_attribute('value'))
        s1.select_by_value("XX3")
        s2 = Select(browser.find_element_by_class_name('selectDestination'))
        # for select in s2.options:
        #     print(select.text)
        s2.select_by_value('XXX')

        # The data table
        browser.execute_script("var t1 = document.getElementsByClassName('datepickerfrom')[0]; t1.value='" +str(tostr)+ "';");
    #         browser.execute_script("var t2 = document.getElementsByClassName('datepickerto')[0]; t2.value='" +str(enstr)+ "';");

        #how many people
    #     browser.execute_script("var t3 = document.getElementsByClassName('total_pass_input')[0]; t3.value=3;");
    #     browser.execute_script("var t2 = document.getElementsByClassName('datepickerto')[0]; t2.value='2019/04/17';");


        browser.find_element_by_css_selector('.btn.btn-primary').submit()
        time.sleep(10)

        try:
            if browser.find_element_by_class_name('error-title') != []:
                print(browser.find_element_by_class_name('error-title').text)
        except:
            time.sleep(10)
            print('no error')
            html = browser.page_source
            soup = bs(html)
            flag = 1
            pass
        if flag == 1:
            break

    except Exception as e:
        print(str(e))
        pass

    browser.quit()
# Out:
# 105 2019/07/26
# page not found
# 106 2019/07/27
# page not found
# 107 2019/07/28
# page not found
# 108 2019/07/29
# page not found
# 109 2019/07/30
# page not found
# 110 2019/07/31
# page not found
# 111 2019/08/01
# page not found
# 112 2019/08/02
# page not found
# 113 2019/08/03
# page not found
# 114 2019/08/04
# page not found
# 115 2019/08/05
# page not found
# 116 2019/08/06
# page not found
# 117 2019/08/07
# page not found
# 118 2019/08/08
# page not found
# 119 2019/08/09
# page not found
# 120 2019/08/10
# page not found
# 121 2019/08/11
# page not found
# 122 2019/08/12
# page not found
# 123 2019/08/13
# page not found
# 124 2019/08/14
# Message: Cannot locate option with value: XXX
#
# 125 2019/08/15
# page not found
# 126 2019/08/16
# page not found
# 127 2019/08/17
# page not found
# 128 2019/08/18
# page not found
# 129 2019/08/19
# page not found
# 130 2019/08/20
# page not found
# 131 2019/08/21
# page not found
# 132 2019/08/22
# page not found
# 133 2019/08/23
# page not found
# 134 2019/08/24
# page not found
# 135 2019/08/25
# page not found
# 136 2019/08/26
# page not found
# 137 2019/08/27
# 224 2019/11/22
# page not found
# 225 2019/11/23
# page not found
# 226 2019/11/24
# page not found
# 227 2019/11/25
# page not found
# 228 2019/11/26
# page not found
# 229 2019/11/27
# page not found
# 230 2019/11/28
# page not found
# 231 2019/11/29
# page not found
# 232 2019/11/30
# page not found
# 233 2019/12/01
# page not found
# 234 2019/12/02
# page not found
# 235 2019/12/03
# page not found
# 236 2019/12/04
# page not found
# 237 2019/12/05
# page not found
# 238 2019/12/06
# page not found
# 239 2019/12/07
# page not found
# 240 2019/12/08
# page not found
# 241 2019/12/09
# page not found
# 242 2019/12/10
# page not found
# 243 2019/12/11
# page not found
# 244 2019/12/12
# page not found
# 245 2019/12/13
# page not found
# 246 2019/12/14
# page not found
# 247 2019/12/15
# page not found
# 248 2019/12/16
# page not found
# 249 2019/12/17
# page not found
# 250 2019/12/18
# page not found
# 251 2019/12/19
# page not found
# 252 2019/12/20
# page not found
# 253 2019/12/21
# page not found
# 254 2019/12/22
# page not found
# 255 2019/12/23
# page not found
# 256 2019/12/24
# page not found
# 257 2019/12/25
# page not found
# 258 2019/12/26
# page not found
# 259 2019/12/27
# page not found
# 260 2019/12/28
# page not found
# 261 2019/12/29
# page not found
# 262 2019/12/30
# page not found
# 263 2019/12/31
# page not found
# 264 2020/01/01
# page not found
# 265 2020/01/02
# page not found
# 266 2020/01/03
# page not found
# 267 2020/01/04
# page not found
# 268 2020/01/05
# page not found
# 269 2020/01/06
# page not found
# 270 2020/01/07
# page not found
# 271 2020/01/08
# page not found
# 272 2020/01/09
# page not found
# 273 2020/01/10
# page not found
# 274 2020/01/11
# page not found
# 275 2020/01/12
# page not found
# 276 2020/01/13
# page not found
# 277 2020/01/14
# page not found
# 278 2020/01/15
# page not found
# 279 2020/01/16
# Message: Cannot locate option with value: XXX
#
# 280 2020/01/17
# page not found
# 281 2020/01/18
# page not found
# 282 2020/01/19
# page not found
# 283 2020/01/20
# page not found
# 284 2020/01/21
# page not found
# 285 2020/01/22
# page not found
# 286 2020/01/23
# page not found
# 287 2020/01/24
# page not found
# 288 2020/01/25
# page not found
# 289 2020/01/26
# page not found
# 290 2020/01/27
# page not found
# 291 2020/01/28
# page not found
# 292 2020/01/29
# page not found
# 293 2020/01/30
# page not found
# 294 2020/01/31
# page not found
# 295 2020/02/01
# page not found
# 296 2020/02/02
# page not found
# 297 2020/02/03
# page not found
# 298 2020/02/04
# page not found
# 299 2020/02/05
# page not found

# %%
flag = 0
for i in range(300):
    today = datetime.datetime.now() + datetime.timedelta(days=i)
    tostr = today.strftime('%Y/%m/%d')
    #     end_date = today + datetime.timedelta(days=5) + datetime.timedelta(days=i)
    #     enstr = end_date.strftime('%Y/%m/%d')

    browser = webdriver.Chrome(executable_path='driver/chromedriver')
    browser.get('https://www.tigerairt-w.com/zh-tw')
    print(i,tostr)
    #     print(tostr,enstr)

    try:
        time.sleep(4)
        #checkbox
        browser.execute_script("document.getElementsByClassName('class_type')[1].setAttribute('checked', true)")
    #         checkboxs=browser.find_elements_by_class_name('class_type')
    #         for checkbox in checkboxs:
    #             print(checkbox.get_attribute('value'),checkbox.get_attribute('checked')

        # select part
        s1 = Select(browser.find_element_by_class_name('selectOrigin'))
    #     for select in s1.options:
    #         print(select.text, select.get_attribute('value'))
        s1.select_by_value("XX3")
        s2 = Select(browser.find_element_by_class_name('selectDestination'))
        # for select in s2.options:
        #     print(select.text)
        s2.select_by_value('XX4')

        # The data table
        browser.execute_script("var t1 = document.getElementsByClassName('datepickerfrom')[0]; t1.value='" +str(tostr)+ "';");
    #         browser.execute_script("var t2 = document.getElementsByClassName('datepickerto')[0]; t2.value='" +str(enstr)+ "';");

        #how many people
    #     browser.execute_script("var t3 = document.getElementsByClassName('total_pass_input')[0]; t3.value=3;");
    #     browser.execute_script("var t2 = document.getElementsByClassName('datepickerto')[0]; t2.value='2019/04/17';");


        browser.find_element_by_css_selector('.btn.btn-primary').submit()
        time.sleep(10)

        try:
            if browser.find_element_by_class_name('error-title') != []:
                print(browser.find_element_by_class_name('error-title').text)
        except:
            time.sleep(10)
            print('no error')
            html = browser.page_source
            soup = bs(html)
            flag = 1
            pass
        if flag == 1:
            break

    except Exception as e:
        print(str(e))
        pass

    browser.quit()
# Out:
# 0 2019/04/12
# page not found
# 1 2019/04/13
# page not found
# 2 2019/04/14
# page not found
# 3 2019/04/15
# page not found
# 4 2019/04/16
# page not found
# 5 2019/04/17
# page not found
# 6 2019/04/18
# page not found
# 7 2019/04/19
# page not found
# 8 2019/04/20
# page not found
# 9 2019/04/21
# page not found
# 10 2019/04/22
# page not found
# 11 2019/04/23
# page not found
# 12 2019/04/24
# page not found
# 13 2019/04/25
# page not found
# 14 2019/04/26
# page not found
# 15 2019/04/27
# page not found
# 16 2019/04/28
# page not found
# 17 2019/04/29
# page not found
# 18 2019/04/30
# page not found
# 19 2019/05/01
# page not found
# 20 2019/05/02
# page not found
# 21 2019/05/03
# page not found
# 22 2019/05/04
# page not found
# 23 2019/05/05
# page not found
# 24 2019/05/06
# page not found
# 25 2019/05/07
# page not found
# 26 2019/05/08
# page not found
# 27 2019/05/09
# page not found
# 28 2019/05/10
# page not found
# 29 2019/05/11
# page not found
# 30 2019/05/12
# page not found
# 31 2019/05/13
# page not found
# 32 2019/05/14
# page not found
# 33 2019/05/15
# page not found
# 34 2019/05/16
# page not found
# 35 2019/05/17
# page not found
# 36 2019/05/18
# page not found
# 37 2019/05/19
# page not found
# 38 2019/05/20
# page not found
# 39 2019/05/21
# page not found
# 40 2019/05/22
# page not found
# 41 2019/05/23
# page not found
# 42 2019/05/24
# page not found
# 43 2019/05/25
# page not found
# 44 2019/05/26
# page not found
# 45 2019/05/27
# page not found
# 46 2019/05/28
# page not found
# 47 2019/05/29
# page not found
# 48 2019/05/30
# page not found
# 49 2019/05/31
# page not found
# 50 2019/06/01
# page not found
# 51 2019/06/02
# page not found
# 52 2019/06/03
# page not found
# 53 2019/06/04
# page not found
# 54 2019/06/05
# page not found
# 55 2019/06/06
# page not found
# page not found
# 244 2019/12/13
# page not found
# 245 2019/12/14
# page not found
# 246 2019/12/15
# page not found
# 247 2019/12/16
# page not found
# 248 2019/12/17
# page not found
# 249 2019/12/18
# page not found
# 250 2019/12/19
# page not found
# 251 2019/12/20
# page not found
# 252 2019/12/21
# page not found
# 253 2019/12/22
# page not found
# 254 2019/12/23
# page not found
# 255 2019/12/24
# page not found
# 256 2019/12/25
# page not found
# 257 2019/12/26
# page not found
# 258 2019/12/27
# page not found
# 259 2019/12/28
# page not found
# 260 2019/12/29
# page not found
# 261 2019/12/30
# page not found
# 262 2019/12/31
# page not found
# 263 2020/01/01
# page not found
# 264 2020/01/02
# page not found
# 265 2020/01/03
# page not found
# 266 2020/01/04
# page not found
# 267 2020/01/05
# page not found
# 268 2020/01/06
# page not found
# 269 2020/01/07
# page not found
# 270 2020/01/08
# page not found
# 271 2020/01/09
# page not found
# 272 2020/01/10
# page not found
# 273 2020/01/11
# page not found
# 274 2020/01/12
# page not found
# 275 2020/01/13
# page not found
# 276 2020/01/14
# page not found
# 277 2020/01/15
# page not found
# 278 2020/01/16
# page not found
# 279 2020/01/17
# page not found
# 280 2020/01/18
# page not found
# 281 2020/01/19
# page not found
# 282 2020/01/20
# page not found
# 283 2020/01/21
# page not found
# 284 2020/01/22
# page not found
# 285 2020/01/23
# page not found
# 286 2020/01/24
# page not found
# 287 2020/01/25
# page not found
# 288 2020/01/26
# page not found
# 289 2020/01/27
# page not found
# 290 2020/01/28
# page not found
# 291 2020/01/29
# page not found
# 292 2020/01/30
# page not found
# 293 2020/01/31
# page not found
# 294 2020/02/01
# page not found
# 295 2020/02/02
# page not found
# 296 2020/02/03
# page not found
# 297 2020/02/04
# page not found
# 298 2020/02/05
# page not found
# 299 2020/02/06
# page not found

# %%
today = datetime.datetime.now() + datetime.timedelta(days=72)
tostr = today.strftime('%Y/%m/%d')
#     end_date = today + datetime.timedelta(days=5) + datetime.timedelta(days=i)
#     enstr = end_date.strftime('%Y/%m/%d')

browser = webdriver.Chrome(executable_path='driver/chromedriver')
browser.get('https://www.tigerairtw.com/zh-tw')
print(tostr)
#     print(tostr,enstr)

try:
    time.sleep(4)
    #checkbox
    browser.execute_script("document.getElementsByClassName('class_type')[1].setAttribute('checked', true)")
#         checkboxs=browser.find_elements_by_class_name('class_type')
#         for checkbox in checkboxs:
#             print(checkbox.get_attribute('value'),checkbox.get_attribute('checked')

    # select part
    s1 = Select(browser.find_element_by_class_name('selectOrigin'))
#     for select in s1.options:
#         print(select.text, select.get_attribute('value'))
    s1.select_by_value("XX3")
    s2 = Select(browser.find_element_by_class_name('selectDestination'))
    # for select in s2.options:
    #     print(select.text)
    s2.select_by_value('XX8')

    # The data table
    browser.execute_script("var t1 = document.getElementsByClassName('datepickerfrom')[0]; t1.value='" +str(tostr)+ "';");
#         browser.execute_script("var t2 = document.getElementsByClassName('datepickerto')[0]; t2.value='" +str(enstr)+ "';");

    #how many people
#     browser.execute_script("var t3 = document.getElementsByClassName('total_pass_input')[0]; t3.value=3;");
#     browser.execute_script("var t2 = document.getElementsByClassName('datepickerto')[0]; t2.value='2019/04/17';");


    browser.find_element_by_css_selector('.btn.btn-primary').submit()
    time.sleep(10)

    try:
        if browser.find_element_by_class_name('error-title') != []:
            print(browser.find_element_by_class_name('error-title').text)
    except:
        time.sleep(10)
        print('no error')
        html = browser.page_source
        soup = bs(html)

except Exception as e:
    print(str(e))
    pass

browser.quit()
# Out:
# 2019/06/24
# page not found

# %%
菲律賓 - 所有機場 XXX
宿霧 (CEB) CEB
卡里博(長灘島) (KLO) KLO
巴拉望(公主港) (PPS) PPS
北海道地區 - 所有機場 XX2
旭川 (AKJ) AKJ
函館 (HKD) HKD
東北地區 - 所有機場 XX5
花卷 (HNA) HNA
仙台 (SDJ) SDJ
中部地區 - 所有機場 XX6
小松 (KMQ) KMQ
名古屋 (NGO) NGO
關東地區 - 所有機場 XX7
東京羽田 (HND) HND
茨城 (IBR) IBR
東京成田 (NRT) NRT
關西地區 - 所有機場 XX8
大阪 (KIX) KIX
岡山 (OKJ) OKJ
九州地區 - 所有機場 XX9
福岡 (FUK) FUK
佐賀 (HSG) HSG
沖繩 (OKA) OKA
南韓 - 所有機場 XX4
濟州 (CJU) CJU
釜山 (PUS) PUS
大邱 (TAE) TAE
台灣 - 所有機場 XX3
台北(桃園) (TPE) TPE
台中 (RMQ) RMQ
高雄 (KHH) KHH
曼谷(廊曼) (DMK) DMK
澳門 (MFM) MFM

# %%
def scrapeJob(afterday=0, daylength=0,fromwhere='XX3',towhere='XXX'):
    today = datetime.datetime.now() + datetime.timedelta(days=afterday)
    tostr = today.strftime('%Y/%m/%d')
    end_date = today + datetime.timedelta(days=daylength) + datetime.timedelta(days=afterday)
    enstr = end_date.strftime('%Y/%m/%d')

    browser = webdriver.Chrome(executable_path='driver/chromedriver')
    browser.get('https://www.tigerairtw.com/zh-tw')
#     print(tostr)
    

    try:
        time.sleep(4)
        #checkbox
        if daylength == 0:
            browser.execute_script("document.getElementsByClassName('class_type')[1].setAttribute('checked', true)")
    #         checkboxs=browser.find_elements_by_class_name('class_type')
    #         for checkbox in checkboxs:
    #             print(checkbox.get_attribute('value'),checkbox.get_attribute('checked')

        # select part
        s1 = Select(browser.find_element_by_class_name('selectOrigin'))
    #     for select in s1.options:
    #         print(select.text, select.get_attribute('value'))
        s1.select_by_value(fromwhere)
        s2 = Select(browser.find_element_by_class_name('selectDestination'))
        # for select in s2.options:
        #     print(select.text)
        s2.select_by_value(towhere)

        # The data table
        browser.execute_script("var t1 = document.getElementsByClassName('datepickerfrom')[0]; t1.value='" +str(tostr)+ "';");
        if daylength != 0:
            browser.execute_script("var t2 = document.getElementsByClassName('datepickerto')[0]; t2.value='" +str(enstr)+ "';");

        #how many people
    #     browser.execute_script("var t3 = document.getElementsByClassName('total_pass_input')[0]; t3.value=3;");
    #     browser.execute_script("var t2 = document.getElementsByClassName('datepickerto')[0]; t2.value='2019/04/17';");


        browser.find_element_by_css_selector('.btn.btn-primary').submit()
        time.sleep(10)

        try:
            if browser.find_element_by_class_name('error-title') != []:
                print(tostr,enstr)
                print(browser.find_element_by_class_name('error-title').text)
        except:
            print(tostr,enstr)
            print('no error')
            html = browser.page_source
            soup = bs(html)

    except Exception as e:
        print(str(e))
        pass
    browser.quit()

# %%
threads = []
for i in range(300):
    threads.append(threading.Thread(target = scrapeJob, args = (i+72,0,'XX3','XXX')))
    threads[i].start()
    if i %  3 == 0:
        time.sleep(11)

for i in range(300):
    print(i, ' thread has finished')
    threads[i].join()
# Out:
# 2019/05/18 2019/06/23
# page not found
# 2019/05/19 2019/06/25
# page not found
# 2019/05/21 2019/06/29
# page not found
# 2019/05/20 2019/06/27
# page not found
# 2019/05/23 2019/07/03
# page not found
# 2019/05/24 2019/07/05
# page not found
# 2019/05/22 2019/07/01
# page not found
# 2019/05/25 2019/07/07
# page not found
# 2019/05/28 2019/07/13
# page not found
# 2019/06/02 2019/07/23
# page not found
# 2019/05/29 2019/07/15
# page not found
# 2019/06/04 2019/07/27
# page not found
# 2019/06/05 2019/07/29
# page not found
# 2019/06/07 2019/08/02
# page not found
# 2019/05/31 2019/07/19
# page not found
# 2019/06/08 2019/08/04
# page not found
# 2019/06/09 2019/08/06
# page not found
# 2019/06/10 2019/08/08
# page not found
# 2019/06/11 2019/08/10
# no error
# 2019/06/14 2019/08/16
# page not found
# 2019/06/15 2019/08/18
# page not found
# 2019/06/16 2019/08/20
# no error
# 2019/06/06 2019/07/31
# no error
# 2019/06/17 2019/08/22
# no error
# 2019/06/20 2019/08/28
# no error
# 2019/06/18 2019/08/24
# no error
# 2019/06/01 2019/07/21
# no error
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# Exception in thread Thread-284:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 8, in scrapeJob
#     browser.get('https://www.tigerairtw.com/zh-tw')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-316:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 8, in scrapeJob
#     browser.get('https://www.tigerairtw.com/zh-tw')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-309:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 8, in scrapeJob
#     browser.get('https://www.tigerairtw.com/zh-tw')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-280:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 8, in scrapeJob
#     browser.get('https://www.tigerairtw.com/zh-tw')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-276:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 8, in scrapeJob
#     browser.get('https://www.tigerairtw.com/zh-tw')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-293:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 8, in scrapeJob
#     browser.get('https://www.tigerairtw.com/zh-tw')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-311:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 8, in scrapeJob
#     browser.get('https://www.tigerairtw.com/zh-tw')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-318:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 7, in scrapeJob
#     browser = webdriver.Chrome(executable_path='driver/chromedriver')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/chrome/webdriver.py", line 81, in __init__
#     desired_capabilities=desired_capabilities)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 157, in __init__
#     self.start_session(capabilities, browser_profile)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 252, in start_session
#     response = self.execute(Command.NEW_SESSION, parameters)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-305:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 8, in scrapeJob
#     browser.get('https://www.tigerairtw.com/zh-tw')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-277:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 8, in scrapeJob
#     browser.get('https://www.tigerairtw.com/zh-tw')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-294:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 8, in scrapeJob
#     browser.get('https://www.tigerairtw.com/zh-tw')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-315:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 8, in scrapeJob
#     browser.get('https://www.tigerairtw.com/zh-tw')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
# ...
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 8, in scrapeJob
#     browser.get('https://www.tigerairtw.com/zh-tw')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-304:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 8, in scrapeJob
#     browser.get('https://www.tigerairtw.com/zh-tw')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-317:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 7, in scrapeJob
#     browser = webdriver.Chrome(executable_path='driver/chromedriver')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/chrome/webdriver.py", line 81, in __init__
#     desired_capabilities=desired_capabilities)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 157, in __init__
#     self.start_session(capabilities, browser_profile)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 252, in start_session
#     response = self.execute(Command.NEW_SESSION, parameters)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# Exception in thread Thread-319:
# Traceback (most recent call last):
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-49-a61b01ac7f52>", line 7, in scrapeJob
#     browser = webdriver.Chrome(executable_path='driver/chromedriver')
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/chrome/webdriver.py", line 81, in __init__
#     desired_capabilities=desired_capabilities)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 157, in __init__
#     self.start_session(capabilities, browser_profile)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 252, in start_session
#     response = self.execute(Command.NEW_SESSION, parameters)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py", line 319, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 374, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/home/james/.local/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py", line 397, in _request
#     resp = self._conn.request(method, url, body=body, headers=headers)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 72, in request
#     **urlopen_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/request.py", line 150, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/poolmanager.py", line 323, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/james/.local/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/usr/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-705a48aed2e7> in <module>
#       4     threads[i].start()
#       5     if i %  3 == 0:
# ----> 6         time.sleep(8)
#       7
#       8 for i in range(300):
#
# KeyboardInterrupt:
