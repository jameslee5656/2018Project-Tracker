# %%
import datetime
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd

# %%
style.use('ggplot')

web_stats = {'Day':[1,2,3,4,5,6],
             'Visitors':[43,53,23,45,64,34],
             'Bounce_Rate':[54,72,62,54,66,75]}
df = pd.DataFrame(web_stats)
print(df)
print(df.head())
print(df.tail())
print(df.tail(2))
# Out:
#    Day  Visitors  Bounce_Rate
# 0    1        43           54
# 1    2        53           72
# 2    3        23           62
# 3    4        45           54
# 4    5        64           66
# 5    6        34           75
#    Day  Visitors  Bounce_Rate
# 0    1        43           54
# 1    2        53           72
# 2    3        23           62
# 3    4        45           54
# 4    5        64           66
#    Day  Visitors  Bounce_Rate
# 1    2        53           72
# 2    3        23           62
# 3    4        45           54
# 4    5        64           66
# 5    6        34           75
#    Day  Visitors  Bounce_Rate
# 4    5        64           66
# 5    6        34           75

# %%
df = df.set_index('Day')
# df.set_index('Day', inplace=True   )

# %%
print(df)
# Out:
#      Visitors  Bounce_Rate
# Day
# 1          43           54
# 2          53           72
# 3          23           62
# 4          45           54
# 5          64           66
# 6          34           75

# %%
print(df.Visitors)
# Out:
# Day
# 1    43
# 2    53
# 3    23
# 4    45
# 5    64
# 6    34
# Name: Visitors, dtype: int64

# %%
print(df[['Bounce_Rate', 'Visitors']])
# Out:
#      Bounce_Rate  Visitors
# Day
# 1             54        43
# 2             72        53
# 3             62        23
# 4             54        45
# 5             66        64
# 6             75        34

# %%
print(df.Visitors.tolist())
# Out:
# [43, 53, 23, 45, 64, 34]

# %%
import numpy as np

# %%
df2 = np.array(df[['Bounce_Rate', 'Visitors']])

# %%
print(df2)
# Out:
# [[54 43]
#  [72 53]
#  [62 23]
#  [54 45]
#  [66 64]
#  [75 34]]

# %%
import quandl
import os

# %%
quandl.ApiConfig.api_key = os.environ.get('quandl_API_KEY')
df = quandl.get('FMAC/HPI_AK')

# %%
df.head()
# Out:
#             NSA Value   SA Value
# Date
# 1975-01-31  34.491826  34.690429
# 1975-02-28  34.990303  35.162914
# 1975-03-31  35.501729  35.544504
# 1975-04-30  36.035816  35.922629
# 1975-05-31  36.620436  36.332016

# %%
fiddy_states = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')[0]

# %%
for index, row in fiddy_states['Abbr'].iterrows():
    print('FMAC/HPI'+row['Abbr'])
# Out:
# FMAC/HPIAL
# FMAC/HPIAK
# FMAC/HPIAZ
# FMAC/HPIAR
# FMAC/HPICA
# FMAC/HPICO
# FMAC/HPICT
# FMAC/HPIDE
# FMAC/HPIFL
# FMAC/HPIGA
# FMAC/HPIHI
# FMAC/HPIID
# FMAC/HPIIL
# FMAC/HPIIN
# FMAC/HPIIA
# FMAC/HPIKS
# FMAC/HPIKY
# FMAC/HPILA
# FMAC/HPIME
# FMAC/HPIMD
# FMAC/HPIMA
# FMAC/HPIMI
# FMAC/HPIMN
# FMAC/HPIMS
# FMAC/HPIMO
# FMAC/HPIMT
# FMAC/HPINE
# FMAC/HPINV
# FMAC/HPINH
# FMAC/HPINJ
# FMAC/HPINM
# FMAC/HPINY
# FMAC/HPINC
# FMAC/HPIND
# FMAC/HPIOH
# FMAC/HPIOK
# FMAC/HPIOR
# FMAC/HPIPA
# FMAC/HPIRI
# FMAC/HPISC
# FMAC/HPISD
# FMAC/HPITN
# FMAC/HPITX
# FMAC/HPIUT
# FMAC/HPIVT
# FMAC/HPIVA
# FMAC/HPIWA
# FMAC/HPIWV
# FMAC/HPIWI
# FMAC/HPIWY

# %%
df1 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2001, 2002, 2003, 2004])

df2 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2005, 2006, 2007, 2008])

df3 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'Low_tier_HPI':[50, 52, 50, 53]},
                   index = [2001, 2002, 2003, 2004])

# %%
concat = pd.concat([df1, df2])
print(concat)
# Out:
#       HPI  Int_rate  US_GDP_Thousands
# 2001   80         2                50
# 2002   85         3                55
# 2003   88         2                65
# 2004   85         2                55
# 2005   80         2                50
# 2006   85         3                55
# 2007   88         2                65
# 2008   85         2                55

# %%
concat = pd.concat([df1, df2, df3])
print(concat)
# Out:
#       HPI  Int_rate  Low_tier_HPI  US_GDP_Thousands
# 2001   80         2           NaN              50.0
# 2002   85         3           NaN              55.0
# 2003   88         2           NaN              65.0
# 2004   85         2           NaN              55.0
# 2005   80         2           NaN              50.0
# 2006   85         3           NaN              55.0
# 2007   88         2           NaN              65.0
# 2008   85         2           NaN              55.0
# 2001   80         2          50.0               NaN
# 2002   85         3          52.0               NaN
# 2003   88         2          50.0               NaN
# 2004   85         2          53.0               NaN
# /home/james/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# ...

# %%
df4 = df1.append(df2)
print(df4)
# Out:
#       HPI  Int_rate  US_GDP_Thousands
# 2001   80         2                50
# 2002   85         3                55
# 2003   88         2                65
# 2004   85         2                55
# 2005   80         2                50
# 2006   85         3                55
# 2007   88         2                65
# 2008   85         2                55

# %%
s = pd.Series([80,2,50], index = ['HPI', 'Int_rate', 'US_GDP_Thousands'])
df4 = df1.append(s, ignore_index=True)
print(df4)
# Out:
#    HPI  Int_rate  US_GDP_Thousands
# 0   80         2                50
# 1   85         3                55
# 2   88         2                65
# 3   85         2                55
# 4   80         2                50

# %%
df1 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2001, 2002, 2003, 2004])

df2 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2005, 2006, 2007, 2008])

df3 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Unemployment':[7, 8, 9, 6],
                    'Low_tier_HPI':[50, 52, 50, 53]},
                   index = [2001, 2002, 2003, 2004])

# %%
print(pd.merge(df1,df2,on=['HPI','Int_rate']))
# Out:
#    HPI  Int_rate  US_GDP_Thousands_x  US_GDP_Thousands_y
# 0   80         2                  50                  50
# 1   85         3                  55                  55
# 2   88         2                  65                  65
# 3   85         2                  55                  55

# %%
# df1.set_index('HPI', inplace=True)
# df3.set_index('HPI', inplace=True)
print(df1)
print(df3)
joined = df1.join(df3)
print(joined)
# Out:
#      Int_rate  US_GDP_Thousands
# HPI
# 80          2                50
# 85          3                55
# 88          2                65
# 85          2                55
#      Unemployment  Low_tier_HPI
# HPI
# 80              7            50
# 85              8            52
# 88              9            50
# 85              6            53
#      Int_rate  US_GDP_Thousands  Unemployment  Low_tier_HPI
# HPI
# 80          2                50             7            50
# 85          3                55             8            52
# 85          3                55             6            53
# 85          2                55             8            52
# 85          2                55             6            53
# 88          2                65             9            50

# %%
df1 = pd.DataFrame({'Year':[2001, 2002, 2003, 2004],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]})


df3 = pd.DataFrame({'Year':[2001, 2003, 2004, 2005],
                    'Unemployment':[7, 8, 9, 6],
                    'Low_tier_HPI':[50, 52, 50, 53]})

# %%
df1.set_index('Year', inplace=True)
df3.set_index('Year', inplace=True)
merged = pd.merge(df1, df3, on='Year')
print(merged)
# Out:
#       Int_rate  US_GDP_Thousands  Unemployment  Low_tier_HPI
# Year
# 2001         2                50             7            50
# 2003         2                65             8            52
# 2004         2                55             9            50

# %%
merged = pd.merge(df1, df3, on='Year', how= 'left')
print(merged)
# Out:
#       Int_rate  US_GDP_Thousands  Unemployment  Low_tier_HPI
# Year
# 2001         2                50           7.0          50.0
# 2002         3                55           NaN           NaN
# 2003         2                65           8.0          52.0
# 2004         2                55           9.0          50.0

# %%
merged = pd.merge(df1, df3, on='Year', how= 'right')
print(merged)
# Out:
#       Int_rate  US_GDP_Thousands  Unemployment  Low_tier_HPI
# Year
# 2001       2.0              50.0             7            50
# 2003       2.0              65.0             8            52
# 2004       2.0              55.0             9            50
# 2005       NaN               NaN             6            53

# %%
merged = pd.merge(df1, df3, on='Year', how= 'outer')# union
print(merged)
# Out:
#       Int_rate  US_GDP_Thousands  Unemployment  Low_tier_HPI
# Year
# 2001       2.0              50.0           7.0          50.0
# 2002       3.0              55.0           NaN           NaN
# 2003       2.0              65.0           8.0          52.0
# 2004       2.0              55.0           9.0          50.0
# 2005       NaN               NaN           6.0          53.0

# %%
merged = pd.merge(df1, df3, on='Year', how= 'inner')# intercept
print(merged)
# Out:
#       Int_rate  US_GDP_Thousands  Unemployment  Low_tier_HPI
# Year
# 2001         2                50             7            50
# 2003         2                65             8            52
# 2004         2                55             9            50

# %%
# Pickling
main_df = pd.DataFrame()
for index, row in fiddy_states['Abbr'].iterrows():
    query = ('FMAC/HPI_'+row['Abbr'])
    df = quandl.get(query)
    print(query)
    if main_df.empty:
        main_df = df
    else:
        main_df = main_df.join(df,rsuffix='_'+row['Abbr'])
print(main_df.head())
# Out:
# FMAC/HPI_AL
# FMAC/HPI_AK
# FMAC/HPI_AZ
# FMAC/HPI_AR
# FMAC/HPI_CA
# FMAC/HPI_CO
# FMAC/HPI_CT
# FMAC/HPI_DE
# FMAC/HPI_FL
# FMAC/HPI_GA
# FMAC/HPI_HI
# FMAC/HPI_ID
# FMAC/HPI_IL
# FMAC/HPI_IN
# FMAC/HPI_IA
# FMAC/HPI_KS
# FMAC/HPI_KY
# FMAC/HPI_LA
# FMAC/HPI_ME
# FMAC/HPI_MD
# FMAC/HPI_MA
# FMAC/HPI_MI
# FMAC/HPI_MN
# FMAC/HPI_MS
# FMAC/HPI_MO
# FMAC/HPI_MT
# FMAC/HPI_NE
# FMAC/HPI_NV
# FMAC/HPI_NH
# FMAC/HPI_NJ
# FMAC/HPI_NM
# FMAC/HPI_NY
# FMAC/HPI_NC
# FMAC/HPI_ND
# FMAC/HPI_OH
# FMAC/HPI_OK
# FMAC/HPI_OR
# FMAC/HPI_PA
# FMAC/HPI_RI
# FMAC/HPI_SC
# FMAC/HPI_SD
# FMAC/HPI_TN
# FMAC/HPI_TX
# FMAC/HPI_UT
# FMAC/HPI_VT
# FMAC/HPI_VA
# FMAC/HPI_WA
# FMAC/HPI_WV
# FMAC/HPI_WI
# FMAC/HPI_WY
#             NSA Value   SA Value  NSA Value_AK  SA Value_AK  NSA Value_AZ  \
# Date
# 1975-01-31  35.692678  35.749768     34.491826    34.690429     28.904632
# 1975-02-28  35.896432  35.962217     34.990303    35.162914     29.405190
# ...

# %%
import pickle #save python data

# %%
def state_list():
    fiddy_states = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')
    return fiddy_states[0]
def grab_initail_state_data():
    states = state_list()
    main_df = pd.DataFrame()
    for index, row in fiddy_states['Abbr'].iterrows():
        query = ('FMAC/HPI_'+row['Abbr'])
        df = quandl.get(query)
        df = df.pct_change()
        if main_df.empty:
            df.rename(columns={'NSA Value':'NSA Value_'+row['Abbr'], 'SA Value':'SA Value_'+row['Abbr']})
            main_df = df
        else:
            main_df = main_df.join(df,rsuffix='_'+row['Abbr'])
    print(main_df.head())
    pickle_out = open('fiddy_states.pickle', 'wb')
    pickle.dump(main_df, pickle_out)
    pickle_out.close()
grab_initail_state_data()
# Out:
#             NSA Value  SA Value  NSA Value_AK  SA Value_AK  NSA Value_AZ  \
# Date
# 1975-01-31        NaN       NaN           NaN          NaN           NaN
# 1975-02-28   0.005709  0.005943      0.014452     0.013620      0.017318
# 1975-03-31   0.006631  0.005196      0.014616     0.010852      0.015958
# 1975-04-30   0.007964  0.006263      0.015044     0.010638      0.012017
# 1975-05-31   0.006966  0.005257      0.016223     0.011396      0.005763
#
#             SA Value_AZ  NSA Value_AR  SA Value_AR  NSA Value_CA  SA Value_CA  \
# Date
# 1975-01-31          NaN           NaN          NaN           NaN          NaN
# 1975-02-28     0.018235      0.007919     0.007933      0.003682     0.004348
# 1975-03-31     0.015630      0.006528     0.006597      0.012366     0.009948
# 1975-04-30     0.010765      0.005093     0.005522      0.019705     0.017099
# 1975-05-31     0.003967      0.005134     0.004405      0.015781     0.014674
#
# ...

# %%
pickle_in = open('fiddy_states.pickle', 'rb')
HPI_data = pickle.load(pickle_in)
print(HPI_data.head())
# Out:
#             NSA Value   SA Value  NSA Value_AK  SA Value_AK  NSA Value_AZ  \
# Date
# 1975-01-31  35.692678  35.749768     34.491826    34.690429     28.904632
# 1975-02-28  35.896432  35.962217     34.990303    35.162914     29.405190
# 1975-03-31  36.134446  36.149066     35.501729    35.544504     29.874429
# 1975-04-30  36.422223  36.375459     36.035816    35.922629     30.233442
# 1975-05-31  36.675944  36.566695     36.620436    36.332016     30.407669
#
#             SA Value_AZ  NSA Value_AR  SA Value_AR  NSA Value_CA  SA Value_CA  \
# Date
# 1975-01-31    28.872477     37.128356    37.025150     15.755165    15.717007
# 1975-02-28    29.398977     37.422378    37.318880     15.813183    15.785352
# 1975-03-31    29.858470     37.666670    37.565069     16.008729    15.942390
# 1975-04-30    30.179901     37.858490    37.772517     16.324174    16.214993
# 1975-05-31    30.299614     38.052842    37.938905     16.581782    16.452939
#
# ...

# %%
# pickle simplify it 
HPI_data.to_pickle('pickle.pickle')
HPI_data2 = pd.read_pickle('pickle.pickle')

# %%
HPI_data['NSA Value_TX2'] = HPI_data['NSA Value_TX'] * 2
print(HPI_data[['NSA Value_TX2','NSA Value_TX']])
# Out:
#             NSA Value_TX2  NSA Value_TX
# Date
# 1975-01-31      65.417405     32.708703
# 1975-02-28      66.029856     33.014928
# 1975-03-31      67.148200     33.574100
# 1975-04-30      68.795988     34.397994
# 1975-05-31      69.235755     34.617878
# 1975-06-30      68.372031     34.186015
# 1975-07-31      67.885276     33.942638
# 1975-08-31      67.929856     33.964928
# 1975-09-30      68.173642     34.086821
# 1975-10-31      68.407233     34.203617
# 1975-11-30      68.788601     34.394301
# 1975-12-31      69.144655     34.572328
# 1976-01-31      69.350484     34.675242
# 1976-02-29      69.895660     34.947830
# 1976-03-31      71.312937     35.656468
# 1976-04-30      73.343217     36.671608
# 1976-05-31      73.962526     36.981263
# 1976-06-30      73.179308     36.589654
# 1976-07-31      72.787321     36.393660
# 1976-08-31      72.793552     36.396776
# 1976-09-30      73.006056     36.503028
# 1976-10-31      73.459956     36.729978
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')

# %%
HPI_data.plot()
plt.legend().remove()
plt.show()

# %%
def state_list():
    fiddy_states = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')
    return fiddy_states[0]
def grab_initail_state_data():
    states = state_list()
    main_df = pd.DataFrame()
    for index, row in fiddy_states['Abbr'].iterrows():
        query = ('FMAC/HPI_'+row['Abbr'])
        df = quandl.get(query)
        df = df.pct_change()
        if main_df.empty:
            df.rename(columns={'NSA Value':'NSA Value_'+row['Abbr'], 'SA Value':'SA Value_'+row['Abbr']})
            main_df = df
        else:
            main_df = main_df.join(df,rsuffix='_'+row['Abbr'])
#     print(main_df.head())
    pickle_out = open('fiddy_states_pct_change.pickle', 'wb')
    pickle.dump(main_df, pickle_out)
    pickle_out.close()
grab_initail_state_data()
# pickle_in = open('fiddy_states.pickle', 'rb')
# HPI_data = pickle.load(pickle_in)

# %%
HPI_data.plot()
plt.legend().remove()
plt.show()

# %%
def state_list():
    fiddy_states = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')
    return fiddy_states[0]
def grab_initail_state_data():
    states = state_list()
    main_df = pd.DataFrame()
    for index, row in fiddy_states['Abbr'].iterrows():
        query = ('FMAC/HPI_'+row['Abbr'])
        df = quandl.get(query)
        df['NSA Value'] = (df['NSA Value'] - df['NSA Value'][0]) / df['NSA Value'][0] * 100.0
        df['SA Value'] = (df['SA Value'] - df['SA Value'][0]) / df['SA Value'][0] * 100.0
        if main_df.empty:
            df.rename(columns={'NSA Value':'NSA Value_'+row['Abbr'], 'SA Value':'SA Value_'+row['Abbr']})
            main_df = df
        else:
            main_df = main_df.join(df,rsuffix='_'+row['Abbr'])
    pickle_out = open('fiddy_states.pickle', 'wb')
    pickle.dump(main_df, pickle_out)
    pickle_out.close()
grab_initail_state_data()
pickle_in = open('fiddy_states.pickle', 'rb')
HPI_data = pickle.load(pickle_in)

# %%
HPI_data.plot()
plt.legend().remove()
plt.show()

# %%
def HPI_Benchmark():
    df = quandl.get('FMAC/HPI_USA')
    df['NSA Value'] = (df['NSA Value'] - df['NSA Value'][0]) / df['NSA Value'][0] * 100.0
    df['SA Value'] = (df['SA Value'] - df['SA Value'][0]) / df['SA Value'][0] * 100.0
    return df

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))

HPI_data = pd.read_pickle('fiddy_states.pickle')
benchmark = HPI_Benchmark()
HPI_data.plot(ax=ax1)
benchmark.plot(ax=ax1, color='k',linewidth=10)

plt.legend().remove()
plt.show()

# %%
HPI_State_Correlation = HPI_data.corr()
print(HPI_State_Correlation.head())
# Out:
#               NSA Value  SA Value  NSA Value_AK  SA Value_AK  NSA Value_AZ  \
# NSA Value      1.000000  0.999791      0.954914     0.954680      0.945081
# SA Value       0.999791  1.000000      0.954724     0.954884      0.945149
# NSA Value_AK   0.954914  0.954724      1.000000     0.999780      0.924330
# SA Value_AK    0.954680  0.954884      0.999780     1.000000      0.924327
# NSA Value_AZ   0.945081  0.945149      0.924330     0.924327      1.000000
#
#               SA Value_AZ  NSA Value_AR  SA Value_AR  NSA Value_CA  \
# NSA Value        0.944901      0.995811     0.995643      0.947641
# SA Value         0.945199      0.995689     0.995837      0.947640
# NSA Value_AK     0.924143      0.973363     0.973192      0.933082
# SA Value_AK      0.924373      0.973207     0.973345      0.933026
# NSA Value_AZ     0.999926      0.945186     0.945189      0.981406
#
#               SA Value_CA  ...  NSA Value_VA  SA Value_VA  NSA Value_WA  \
# ...

# %%
HPI_State_Correlation.describe()
# Out:
#         NSA Value    SA Value  NSA Value_AK  SA Value_AK  NSA Value_AZ  \
# count  100.000000  100.000000    100.000000   100.000000    100.000000
# mean     0.970886    0.970930      0.946246     0.946244      0.942077
# std      0.023414    0.023382      0.036057     0.036093      0.022837
# min      0.890676    0.890860      0.806682     0.806293      0.878520
# 25%      0.955281    0.955343      0.933032     0.933084      0.931352
# 50%      0.975801    0.975881      0.954674     0.954595      0.943675
# 75%      0.986741    0.986685      0.966317     0.966504      0.952982
# max      1.000000    1.000000      1.000000     1.000000      1.000000
#
#        SA Value_AZ  NSA Value_AR  SA Value_AR  NSA Value_CA  SA Value_CA  ...  \
# count   100.000000    100.000000   100.000000    100.000000   100.000000  ...
# mean      0.942022      0.972832     0.972835      0.952407     0.952368  ...
# std       0.022851      0.023206     0.023202      0.020008     0.020022  ...
# ...

# %%
# Resampling
# %matplotlib notebook
fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))
HPI_data = pd.read_pickle('fiddy_states.pickle')
TX1yr = HPI_data['SA Value_TX'].resample('A').mean()
HPI_data['SA Value_TX'].plot(ax = ax1, label='Monthly TX HPI')
TX1yr.plot(ax = ax1, label='Yearly TX HPI')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="942.4">

# %%
# Resampling
# %matplotlib notebook
fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))
HPI_data = pd.read_pickle('fiddy_states.pickle')
TX1yr = HPI_data['SA Value_TX'].resample('A').ohlc()
HPI_data['SA Value_TX'].plot(ax = ax1, label='Monthly TX HPI')
TX1yr.plot(ax = ax1, label='Yearly TX HPI')
plt.legend(loc=4)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="926.4">

# %%
# Handling Missing Data -> delete it that is Nan
HPI_data = pd.read_pickle('fiddy_states.pickle')
HPI_data['TX1yr'] = HPI_data['SA Value_TX'].resample('A').mean()
print(HPI_data[['SA Value_TX', 'TX1yr']].head())
HPI_data.dropna(inplace=True)
print(HPI_data[['SA Value_TX', 'TX1yr']].head())
# Out:
#             SA Value_TX  TX1yr
# Date
# 1975-01-31     0.000000    NaN
# 1975-02-28     0.835071    NaN
# 1975-03-31     2.251173    NaN
# 1975-04-30     4.648140    NaN
# 1975-05-31     5.127002    NaN
#             SA Value_TX      TX1yr
# Date
# 1975-12-31     5.713637   3.344527
# 1976-12-31    13.977155  10.493683
# 1977-12-31    28.736814  21.507743
# 1978-12-31    48.822940  39.432122
# 1979-12-31    74.205257  61.983882

# %%
# Handling Missing Data -> delete it that is Not a number
HPI_data = pd.read_pickle('fiddy_states.pickle')
HPI_data['TX1yr'] = HPI_data['SA Value_TX'].resample('A').mean()
print(HPI_data[['SA Value_TX', 'TX1yr']].head())
HPI_data.dropna(how='all', inplace=True) # may use a 'thresh' threshold to filter the data
print(HPI_data[['SA Value_TX', 'TX1yr']].head())
# Out:
#             SA Value_TX  TX1yr
# Date
# 1975-01-31     0.000000    NaN
# 1975-02-28     0.835071    NaN
# 1975-03-31     2.251173    NaN
# 1975-04-30     4.648140    NaN
# 1975-05-31     5.127002    NaN
#             SA Value_TX  TX1yr
# Date
# 1975-01-31     0.000000    NaN
# 1975-02-28     0.835071    NaN
# 1975-03-31     2.251173    NaN
# 1975-04-30     4.648140    NaN
# 1975-05-31     5.127002    NaN

# %%
# Handling Missing Data -> delete it that is Not a number
# %matplotlib notebook
fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))
HPI_data = pd.read_pickle('fiddy_states.pickle')
HPI_data['TX1yr'] = HPI_data['SA Value_TX'].resample('A').mean()
# print(HPI_data[['SA Value_TX', 'TX1yr']].head())
HPI_data.fillna(method='ffill',inplace=True) # Take data before fill it
# print(HPI_data[['SA Value_TX', 'TX1yr']].head())
HPI_data['SA Value_TX'].plot(ax = ax1, label='Monthly TX HPI')
HPI_data['TX1yr'].plot(ax = ax1, label='Yearly TX HPI')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Handling Missing Data -> delete it that is Not a number
# %matplotlib notebook
fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))
HPI_data = pd.read_pickle('fiddy_states.pickle')
HPI_data['TX1yr'] = HPI_data['SA Value_TX'].resample('A').mean()
# print(HPI_data[['SA Value_TX', 'TX1yr']].head())
HPI_data.fillna(method='bfill',inplace=True) # Take data back fill it
# print(HPI_data[['SA Value_TX', 'TX1yr']].head())
HPI_data['SA Value_TX'].plot(ax = ax1, label='Monthly TX HPI')
HPI_data['TX1yr'].plot(ax = ax1, label='Yearly TX HPI')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Handling Missing Data -> delete it that is Not a number
# %matplotlib notebook
fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))
HPI_data = pd.read_pickle('fiddy_states.pickle')
HPI_data['TX1yr'] = HPI_data['SA Value_TX'].resample('A').mean()
# print(HPI_data[['SA Value_TX', 'TX1yr']].head())
HPI_data.fillna(value=-99999,inplace=True) # machine learning may ignore this kind of data
# print(HPI_data[['SA Value_TX', 'TX1yr']].head())
HPI_data['SA Value_TX'].plot(ax = ax1, label='Monthly TX HPI')
HPI_data['TX1yr'].plot(ax = ax1, label='Yearly TX HPI')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# # Handling Missing Data -> delete it that is Not a number
# %matplotlib notebook
# fig = plt.figure()
# ax1 = plt.subplot2grid((1,1), (0,0))
HPI_data = pd.read_pickle('fiddy_states.pickle')
HPI_data['TX1yr'] = HPI_data['SA Value_TX'].resample('A').mean()
# print(HPI_data[['SA Value_TX', 'TX1yr']].head())
HPI_data.fillna(value=-99999,inplace=True,limit=10) # let your filling have some kind of limit
# print(HPI_data[['SA Value_TX', 'TX1yr']].head())
# HPI_data['SA Value_TX'].plot(ax = ax1, label='Monthly TX HPI')
# HPI_data['TX1yr'].plot(ax = ax1, label='Yearly TX HPI')
# plt.legend()
# plt.show()
print(HPI_data.isnull().values.sum())
# Out:
# 476

# %%
# Rolling stats
# %matplotlib notebook
fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))

HPI_data = pd.read_pickle('fiddy_states.pickle')
HPI_data['TX12MA'] = HPI_data['SA Value_TX'].rolling(12).mean() # start latter
print(HPI_data[['SA Value_TX', 'TX12MA']].head())
HPI_data[['SA Value_TX','TX12MA']].plot(ax = ax1)

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="936">
#             SA Value_TX  TX12MA
# Date
# 1975-01-31     0.000000     NaN
# 1975-02-28     0.835071     NaN
# 1975-03-31     2.251173     NaN
# 1975-04-30     4.648140     NaN
# 1975-05-31     5.127002     NaN

# %%
# %matplotlib notebook
fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))

HPI_data = pd.read_pickle('fiddy_states.pickle')
HPI_data['TX12MA'] = HPI_data['SA Value_TX'].rolling(120).mean() # start latter
print(HPI_data[['SA Value_TX', 'TX12MA']].head())
HPI_data.dropna(inplace=True)
HPI_data[['SA Value_TX','TX12MA']].plot(ax = ax1)

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
#             SA Value_TX  TX12MA
# Date
# 1975-01-31     0.000000     NaN
# 1975-02-28     0.835071     NaN
# 1975-03-31     2.251173     NaN
# 1975-04-30     4.648140     NaN
# 1975-05-31     5.127002     NaN

# %%
# %matplotlib notebook
fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))

HPI_data = pd.read_pickle('fiddy_states.pickle')
HPI_data['TX12MA'] = HPI_data['SA Value_TX'].rolling(12).std()
# print(HPI_data[['SA Value_TX', 'TX12MA']].head())
# HPI_data.dropna(inplace=True)
HPI_data[['SA Value_TX','TX12MA']].plot(ax = ax1)

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
fig = plt.figure()
ax1 = plt.subplot2grid((2,1), (0,0))
ax2 = plt.subplot2grid((2,1), (1,0), sharex=ax1)


HPI_data = pd.read_pickle('fiddy_states.pickle')
HPI_data['TX12MA'] = HPI_data['SA Value_TX'].rolling(12).mean()
HPI_data['TX12STD'] = HPI_data['SA Value_TX'].rolling(12).std()
# print(HPI_data[['SA Value_TX', 'TX12MA']].head())
# HPI_data.dropna(inplace=True)
HPI_data[['SA Value_TX','TX12MA']].plot(ax = ax1)
HPI_data[['TX12STD']].plot(ax = ax2)


plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="838.4">

# %%
# %matplotlib notebook
fig = plt.figure()
ax1 = plt.subplot2grid((2,1), (0,0))
ax2 = plt.subplot2grid((2,1), (1,0), sharex=ax1)

HPI_data = pd.read_pickle('fiddy_states.pickle')
TX_AK_12corr = HPI_data['SA Value_TX'].rolling(12).corr(HPI_data['SA Value_AK'])
HPI_data['SA Value_TX'].plot(ax=ax1, label='TX HPI')
HPI_data['SA Value_AK'].plot(ax=ax1, label='AK HPI')
ax1.legend(loc=4)
TX_AK_12corr.plot(ax=ax2, label='TX_AK_12corr')

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="878.4">

# %%
# Applying Comparison operation

# removing something is not realistic
bridge_height = {'meters':[10.26, 10.31, 10.27, 10.22, 10.23, 6212.42, 10.28, 10.25, 10.31]}
df = pd.DataFrame(bridge_height)
df.plot()
plt.show()
#  6212.42 is a erroneous data
# Out:
# <img src="data:image/png;base64,..." width="485.6">

# %%
df = pd.DataFrame(bridge_height)
df.plot()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# how to detect this ==> std 
df['STD'] = df['meters'].rolling(2).std()
print(df['STD'])
df.plot()
plt.show()
# Out:
# 0            NaN
# 1       0.035355
# 2       0.028284
# 3       0.035355
# 4       0.007071
# 5    4385.610607
# 6    4385.575252
# 7       0.021213
# 8       0.042426
# Name: STD, dtype: float64
# <img src="data:image/png;base64,..." width="640">

# %%
# Derive x that std is to big and remove it
df.describe()
# Out:
#             meters          STD
# count     9.000000     8.000000
# mean    699.394444  1096.419446
# std    2067.384584  2030.121949
# min      10.220000     0.007071
# 25%      10.250000     0.026516
# 50%      10.270000     0.035355
# 75%      10.310000  1096.425633
# max    6212.420000  4385.610607

# %%
df_std = df.describe()['meters']['std']
print(df_std)
# Out:
# 2067.3845835687607

# %%
df = df[ (df['STD'] < df_std) ]
print(df)# we remove it
df['meters'].plot()
plt.show()
# Out:
#    meters       STD
# 1   10.31  0.035355
# 2   10.27  0.028284
# 3   10.22  0.035355
# 4   10.23  0.007071
# 7   10.25  0.021213
# 8   10.31  0.042426
# <img src="data:image/png;base64,..." width="640">

# %%
# this is a example
def mortgage_30y():
    df = quandl.get('FMAC/MORTG', trim_start='1979-01-01')
    df['Value'] = (df['Value'] - df['Value'][0]) / df['Value'][0] * 100.0
    df = df.resample('D').interpolate()
    df = df.resample('M').interpolate()
    df.columns = ['M30']
#     print(df.describe())
    return df
HPI_data = pd.read_pickle('fiddy_states.pickle')
HPI_bench = HPI_Benchmark()
m30 = mortgage_30y()
states_HPI_M30 = HPI_data.join(m30)
print(states_HPI_M30.corr()['M30'].describe())
# Out:
# count    101.000000
# mean      -0.818864
# std        0.189868
# min       -0.903744
# 25%       -0.871568
# 50%       -0.843166
# 75%       -0.819826
# max        1.000000
# Name: M30, dtype: float64

# %%
def sp500_data():
    df = quandl.get("MULTPL/SP500_DIV_YIELD_MONTH", trim_start="1975-01-01")
    df["Value"] = (df["Value"]-df["Value"][0]) / df["Value"][0] * 100.0
    df=df.resample('M').mean()
    df.rename(columns={'Value':'sp500'}, inplace=True)
    df = df['sp500']
    return df

def gdp_data():
    df = quandl.get("BCB/4385", trim_start="1975-01-01")
    df["Value"] = (df["Value"]-df["Value"][0]) / df["Value"][0] * 100.0
    df=df.resample('M').mean()
    df.rename(columns={'Value':'GDP'}, inplace=True)
    df = df['GDP']
    return df

def us_unemployment():
    df = quandl.get("FRED/NROUST", trim_start="1975-01-01")
    df["Value"] = (df["Value"]-df["Value"][0]) / df["Value"][0] * 100.0
    df=df.resample('1D').mean()
    df=df.resample('M').mean()
    return df

HPI_data = pd.read_pickle('fiddy_states.pickle')
m30 = mortgage_30y()
sp500 = sp500_data()
gdp = gdp_data()
HPI_Bench = HPI_Benchmark()
unemployment = us_unemployment()
m30.columns=['M30']
HPI = HPI_Bench.join([m30,sp500,gdp,unemployment])
HPI.dropna(inplace=True)
print(HPI.corr())
# Out:
#            NSA Value  SA Value       M30     sp500       GDP     Value
# NSA Value   1.000000  0.999485 -0.764033 -0.372709  0.611227 -0.655655
# SA Value    0.999485  1.000000 -0.765156 -0.372737  0.610049 -0.655432
# M30        -0.764033 -0.765156  1.000000  0.355921 -0.824724  0.368486
# sp500      -0.372709 -0.372737  0.355921  1.000000 -0.122702  0.426070
# GDP         0.611227  0.610049 -0.824724 -0.122702  1.000000 -0.072542
# Value      -0.655655 -0.655432  0.368486  0.426070 -0.072542  1.000000

# %%
housing_data = pd.read_pickle('fiddy_states.pickle')
housing_data = housing_data.pct_change()

# %%
import numpy as np

# %%
housing_data.replace([np.inf, -np.inf], np.nan, inplace=True)
housing_data['US_HPI_future'] = housing_data['NSA Value'].shift(-1)
housing_data.dropna(inplace=True)
def create_labels(cur_hpi, fut_hpi):
    if fut_hpi > cur_hpi:
        return 1
    else:
        return 0
housing_data['label'] = list(map(create_labels,housing_data['NSA Value'], housing_data['US_HPI_future']))

# %%
print(housing_data.head())
# Out:
#             NSA Value  SA Value  NSA Value_AK  SA Value_AK  NSA Value_AZ  \
# Date
# 1975-03-31   1.168145  0.879507      1.025975     0.807624      0.937430
# 1975-04-30   0.651420  0.566977      0.528850     0.442730      0.370194
# 1975-05-31   0.347779  0.305640      0.378642     0.332241      0.131115
# 1975-06-30   0.097704  0.069268      0.295418     0.254091     -0.049459
# 1975-07-31  -0.109168 -0.139568      0.229717     0.226937     -0.237494
#
#             SA Value_AZ  NSA Value_AR  SA Value_AR  NSA Value_CA  SA Value_CA  \
# Date
# 1975-03-31     0.872730      0.830861     0.838145      3.370423     2.297752
# 1975-04-30     0.325998      0.356336     0.384221      1.244046     1.209509
# 1975-05-31     0.091564      0.266186     0.222632      0.452731     0.477818
# 1975-06-30    -0.097495      0.234169     0.224077      0.129532     0.113632
# 1975-07-31    -0.258001      0.158748     0.114617      0.123229     0.085240
#
# ...

# %%
def moving_average(values):
    ma = mean(values)
    return ma

# %%
housing_data['ma_apply_example'] = housing_data['M30'].rolling(10).apply(moving_average)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'm30'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-350-5207acb65a4c> in <module>
# ...
